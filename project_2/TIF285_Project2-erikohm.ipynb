# %% [markdown]
# # Project 2: Newton vs the machine: <br/>*solving the chaotic three-body problem using deep neural networks*
# ## Learning from data [TIF285], Chalmers, Fall 2023
#
# Last revised: 15-Sep-2023 by Christian Forssén [christian.forssen@chalmers.se]

# %% [markdown]
# ## Instructions

# %% [markdown]
# - See deadline on the course web page
# - This project is performed in groups of two students.
# - The second part of the project is optional. See examination rules on the course web page.
# - Hand-in your written report and your solution source code via Canvas.
# - Please also upload your ANN model with the trained parameters as `myNN.keras` using the keras `save_model` method: `tf.keras.models.save_model(model, 'myNN.keras')`, which employs the native Keras file format.

# %% [markdown]
# ### Written report
# - Page limit: 6 pages (excluding title page and list of references). 3 extra pages are allowed when doing also the optional extra task.
# - Give a short description of the nature of the problem and the methods you have used.
# - Include your results either in figure form or in a table. All tables and figures should have relevant captions and labels on the axes.
# - Try to give an interpretation of you results.
# - Upload the source code of your program as a separate file (.ipynb or .py). Comment your program properly.

# %% [markdown]
# ### Learning goals:
# * Apply deep neural networks to build an emulator for a physics problem that is difficult and costly to solve numerically.
# * Get familiar with [tensorflow](https://www.tensorflow.org/), the popular open-source library to train ML models created by the Google Brain team.
# * Get experience with some diagnostics used in the training of neural networks.
# * Understand the difficulties and choices involved when training a deep neural network.
# * This is a less-guided set of tasks and you will have to put together ideas and tools we've discussed.
# * Reproduce scientific results from a published paper.

# %% [markdown]
# ## Main task
# The overall project goal is to reproduce various results in a paper: [*Newton vs the machine: solving the chaotic three-body problem using deep neural networks*](https://arxiv.org/abs/1910.07291) by Philip G. Breen, Christopher N. Foley, Tjarda Boekholt, Simon Portegies Zwart.
#
# The authors have graciously agreed that we use the raw data from their study for this project (but please don't distribute any further).

# %% [markdown]
# ### Physical problem

# %% [markdown]
# In this project we are studying the motion of three bodies of equal mass that move under the mutual influence of classical gravitational forces. Due to the system's chaotic nature, the solution to this problem for a given initialization can only be found by performing iterative numerical calculations that have unpredictable and potentially very large computational cost.
#
# Here you will demonstrate that a deep artificial neural network (ANN) is able to learn the solutions to the equations of motion from a set of numerical training data. This ANN can then provide good approximations for new initial conditions at a predictable (and small) computational cost.

# %% [markdown]
# The training data that we will be using was generated with a state-of-the-art numerical code `Brutus` [[Boekholt, T., Portegies Zwart, S. On the reliability of N-body simulations. Comput. Astrophys. 2, 2 (2015).](https://doi.org/10.1186/s40668-014-0005-3)]. The run time of that code for the trajectories studied here ranges from minutes up to hours. In the end, it will therefore be relevant to quantify what is the computational cost of making a prediction with our constructed ANN.

# %% [markdown]
# ### Initial condition and choice of coordinates
# - We work in the the center-of-mass (CM) frame and only consider the scenario in which the three masses start from rest.
# - It can be shown that, without loss of generality, it is always possible to choose a coordinate system such that the three particles $p_1, p_2, p_3$ move in a plane so that just $(x,y)$ coordinates are needed.
# - Furthermore, the $(x,y)$ coordinates can be chosen and scaled such that particle 1 starts in position $(1,0)$ and the initial position of particle 2 is located in the second quantile ($x<0$, $y>0$).
# - Since we are in the CM frame and our system consists of three equal masses we will always have $x_1+x_2+x_3=0$ and $y_1+y_2+y_3=0$. Consequently, we can determine the position of particle 3 from knowledge of the positions of particles 1 and 2.
#
# See also Fig. 1 in the paper.

# %% [markdown]
# ### Data
# The data that you should use is made available as a compressed numpy file on the Canvas course page. Note that, due to its size, it is not included in the `tif285` git repo.
#
# Navigate to Files > Project2  and download `data_project2.npz`.

# %%
# Load modules
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Add your own import statements if needed

# %%
# Load and unpack a compressed npy array
load_data = np.load('data_project2.npz')
data = load_data['arr_0']
print(data.shape)
timestep = 1000
#normalize data
# Out:
# (9000, 1000, 9)

# %% [markdown]
# - The first axis labels the 9000 data samples.
# - The second axis is the 1000 time steps, which corresponds to 3.9 time units. The original data is composed of 2561 time steps, reaching 10 time units, but as discussed in the paper the training of the ANN works better for the somewhat shorter time interval.
# - The nine columns of the last axis correspond to: $[t, x_1, y_1, x_2, y_2, v_{x,1}, v_{y,1}, v_{x,2}, v_{y,2}]$ (note again that the position of particle 3 can be obtained from the positions of particles 1 and 2). The velocity data is only used in the extra task.
# - Some of the trajectories contain collisions such that the positions of the particles get stuck at (0, 0). Check the data to find those trajectories and remove them before training your model.
# - Note that the trajectories are represented by data points in sets of 1000 (time steps). While creating batches of data, make sure you are not mixing part of the data from one trajectory with a different trajectory.

# %% [markdown]
# ### List of tasks
# 1. Download and load the pre-trained ANN from the paper (see below) and construct your own ANN using the provided data. Compare the complexity (number of trainable parameters) in the pre-trained versus your own ANN.
# 1. Show the Mean Absolute Error (MAE) vs epoch from the training of your own ANN (as in Fig. 3 of the paper). I.e. you should show both the MAE metric on the training and the validation data.
# 1. Check the accuracy of the pre-trained ANN by showing some trajectories and the ANN prediction as in Fig. 4 of the paper. Add also the trajectory of your ANN and comment on its performance. (Note that you should not expect your own ANN to perform as well as the pre-trained one. In addition, the trajectories that are shown in the paper seem to be ones for which the model works very well).
# 1. Check the computational cost of making a prediction with the ANN. You will find that it is much shorter than the numerical integration performed by `Brutus` (which according to the reference takes minutes to hours for finding a trajectory).
# 1. Having access to these ANN emulators you can explore the chaotic aspect of this motion by creating a hundred different trajectories from a slightly disturbed initial condition. Try to reproduce Fig. 5 in the paper (both with the pre-trained and your own ANN).

# %% [markdown]
# ### Suggestions for how to proceed:
# * Follow the lead of the demo notebook for using tensorflow / keras (plus see the hints below).
# * First download and load the data set and the ANN from the paper (both available on the Canvas course page. Navigate to Files > Project2; see hint below)
# * It is suggested (but not required) to create helper functions (see hints below):
#   * `get_data` for extracting a trajectory (positions of particle 1 as a function of the discrete time) from the data;
#   * `get_trajectories` for generating the positions of all particles from a prediction output that contains the arrays of the first two particles' positions;
#   * `plot_trajectories` for plotting a trajectory.
# * When creating your own ANN it is suggested that you first design a smaller one than in the paper (e.g., using five dense layers with 64 neurons in each) and analyse how it performs by looking at the training vs validation error. The creation of a large network with ten layers and 128 nodes per layer is optional (and might require more cpu-hours for training).
# * Try first with the `relu` activation function and the `Adam` optimizer with a learning rate of 0.001 and moments of 0.5 (these hyper-parameters can easily be changed if you want; see hints below).
#     - The choice of optimizer  and hyper-parameters such as learning rate can certainly influence your results. For the interested, an extensive guide with open-source experimental results is published here: https://arxiv.org/abs/2007.01547.
# * Use 90% of the data for training and 10% for validation. You probably need at least hundred epochs for training and it is suggested to split the data into 10-100 batches (see hints below).

# %% [markdown]
# ### Comments and hints
# * Download the pre-trained ANN model (<a href="https://chalmers.instructure.com/files/1674480/download?download_frd=1" title="Breen_NN_project2.h5" class="instructure_file_link">Breen_NN_project2.h5</a>) and load it with: `pre_trained_model = keras.models.load_model("Breen_NN_project2.h5")`. This file should also be included in the gzipped tarball that contains the project 2 files.
# * The ANN input should be an array with three elements: $[t,x_2,y_2]$, where the last two will be the initial position of particle 2 and the first one is the time step for which the particle positions should be predicted. Remember that particle 1 always starts in $(1,0)$.
# * Input data corresponding to a single trajectory is then of shape $1000 \times 3$ where the first column contains the time steps while the $x_2,y_2$ columns are repetitions of the initial position.
# * I.e., the inputs to the `tensorflow` network is a tensor with three columns where the second and third columns have values that are repeated (with values of the initial position at [t=0]) for all the rows corresponding to a single trajectory.
# * The output should be an array with four elements $[x_1,y_1,x_2,y_2]$ that corresponds to the positions of particles 1 and 2 at the time step $t$ that was given in the first position of the input. Again, we can consider a tensor (batch) of outputs corresponding, e.g., to a full trajectory.
# * As mentioned, some of the trajectories contain collisions such that the positions of the particles get stuck at (0, 0). Check the data to find those trajectories and remove them before training your model.
# * The data can be turned into a `tensorflow` dataset using: `dataset = tf.data.Dataset.from_tensor_slices((x, y))`, where `x` and `y` are input and output data, respectively (you might possibly need to reshape using `x.reshape(-1, 3)` and `y.reshape(-1, 4)`)
# * Having created a dataset, e.g. `train_dataset`, you can make batches (e.g. with batchsize 5000) with `train_dataset = train_dataset.batch(5000)`. The same should then be done for the validation data. As mentioned, the trajectories are represented by data points in sets of 1000 (time steps). While creating batches of data, make sure you are not mixing part of the data from one trajectory with a different trajectory.
# * When compiling a `tensorflow` model, with `model.compile()`, the Adam optimizer can be specified via the argument `optimizer=keras.optimizers.Adam(0.001, 0.5, 0.5)`
# * Furthermore, the loss function can be chosen using the argument `loss=keras.losses.MeanAbsoluteError()`
# * Fitting the model for 100 epochs with specified training and validation data sets can be performed with: `model.fit(train_dataset, epochs=100, validation_data = val_dataset)`
# * Given the cost of training the network with all data, it is not required to make extensive tests of tuning the hyperparameters.
# * More exact timing of a function can be measured using ["Jupyter notebook magic"](https://towardsdatascience.com/the-top-5-magic-commands-for-jupyter-notebooks-2bf0c5ae4bb8) by putting the command to be measured in a notebook cell that starts with `%timeit`. This will run the cell many times and report the mean and standard deviation of the evaluation time.

# %% [markdown]
# #### Helper function docstrings
# The following are just suggestions. You are allowed to construct a solution using your own helper functions.

# %%
timesteps=1000
data_indices=np.arange(0,len(data))
correct_indices=[]
for index in data_indices:
    if (np.abs(data[index, timestep-1, 1])+np.abs(data[index, timestep-1, 2]) > 0.001) & (np.abs(data[index, timestep-1, 3])+np.abs(data[index, timestep-1, 4]) > 0.001):
        correct_indices.append(index)

np.random.shuffle(correct_indices)

index_90 = int(len(correct_indices)*0.9)  #shuffle data and perform training validation split

train_indices = np.array(correct_indices[0:index_90])

val_indices = np.array(correct_indices[index_90:])

# %%
def get_data(idx):
    """
    Get one training instance from the data set at the index idx. 
    
    The data is assumed to be in an array `data`.
    
    Args:
        idx (int): An integer specifying which of the training example to fetch
        
    Returns:
        x (array): An array of shape (time_steps, 3) which specifies the input to
                   the neural network. The first column is the time and the second
                   and third columns specify the (x, y) coordinates of the second
                   particle. Note that the first particle is always assumed to be
                   at (1, 0) and the third particle can be inferred from the first
                   and second particle's position.
                   
        y (array): An array of shape (time_steps, 4) which specifies the output that 
                   is expected from the neural network.
                   
                   The first two columns specify the (x, y) coordinates of the first
                   particles and the next two columns give the coordinates of the 
                   second particle for the specified time (length of the columns).
                   The third particles position can be inferred from the first
                   and second particle's position.
    """

    timesteps=1000

    
    x_0=np.array(data[idx,0,[0,3,4]])
    x = np.tile(x_0, (timesteps, 1))
    x[:,0] = data[idx,:,0]

    y = data[[idx], : ,[1,2,3,4]].T
    
    
    return x, y

# %%
def get_chaotic_x2():

    theta = np.random.uniform(0,2*np.pi)
    R=0.01
    
    x_0_x = -0.2 + R*np.cos(theta)
    x_0_y = 0.3 + R*np.sin(theta)
    
    x_0 = np.array([0, x_0_x, x_0_y])
    x = np.tile(x_0, (timesteps, 1))
    x[:,0] = data[0,:,0]
    
    c_0 = np.array([0, -0.2, 0.3])
    c = np.tile(c_0, (timesteps, 1))
    c[:,0] = data[0,:,0]

    return x, c

# %%
def get_trajectories(pred):
    """
    Gets the trajectories from a predicted output pred.
    
    Args:
        pred (array): An array of shape (N, 4) where N is the number of time
                      steps. The four columns give the positions of the particles
                      1 and 2 for all the time steps.
    Returns:
        p1, p2, p3 (tuple of arrays): Three arrays of dimensions (N, 2) where N is the number 
                             of time steps and the two columns for each array give 
                             the positions of the three particles (p1, p2, p3)
    """

    timesteps = 1000
    
    p1 = pred[:,0:2]
    p2 = pred[:,2:4]

    p3 = np.zeros((timesteps,2))

    
    p3_x= -(p1[:,0]+p2[:,0]) #x1+x2+x3=0, y1+y2+y3=0
    p3_y= -(p1[:,1]+p2[:,1])
    p3[:,0], p3[:,1] = p3_x, p3_y



    return p1,p2,p3

# %%
def plot_trajectories(p1, p2, p3, ax=None, **kwargs):
    """
    Plots trajectories for points p1, p2, p3
    
    Args:
        p1, p2, p3 (array): Three arrays each of shape (n, 2) where n is the number
                            of time steps. Each array is the (x, y) position for the
                            particles
        ax (axis object): Default None, in which case a new axis object is created.
        kwargs (dict): Optional keyword arguments for plotting
        
    Returns:
        ax: Axes object
    """
    
    if ax is None:
        fig, ax = plt.subplots(1,1)

    ax.plot(p1[:,0], p1[:,1], label='p1',color='r')
    ax.scatter(p1[0,0], p1[0,1],color='r')
    ax.plot(p2[:,0], p2[:,1], label='p2',color='b')
    ax.scatter(p2[0,0], p2[0,1],color='b')
    ax.plot(p3[:,0], p3[:,1], label='p3',color='g')
    ax.scatter(p3[0,0], p3[0,1],color='g')
    
    #plt.legend()
    

    
    return ax

# %%
pre_trained_model = keras.models.load_model("Breen_NN_project2.h5")

# %%
timesteps=1000

x_train = np.zeros((len(train_indices),timesteps,3))
y_train = np.zeros((len(train_indices),timesteps,4))

x_val = np.zeros((len(val_indices),timesteps,3))
y_val = np.zeros((len(val_indices),timesteps,4))


for i in range(len(train_indices)):

        x, y = get_data(train_indices[i])
        x_train[i] = x
        y_train[i] = y

x_train = x_train.reshape(-1, 3)
y_train = y_train.reshape(-1, 4)

for i in range(len(val_indices)):

        x,y = get_data(val_indices[i])
        x_val[i] = x
        y_val[i] = y

x_val = x_val.reshape(-1, 3)
y_val = y_val.reshape(-1, 4)

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))

train_dataset = train_dataset.batch(5000, drop_remainder=True)
val_dataset = val_dataset.batch(5000, drop_remainder=True)

# %%
model = tf.keras.models.Sequential([
      tf.keras.layers.InputLayer(input_shape=(3)),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dense(4, activation='linear')
])

# %%
#model.compile(optimizer=keras.optimizers.Adam(0.001, 0.5, 0.5), loss=keras.losses.MeanAbsoluteError(), metrics=['mean_absolute_error'])

# %%
#history = model.fit(train_dataset, batch_size=5000, epochs=100, validation_data=val_dataset)
#tf.keras.models.save_model(model, 'myNN128.keras')
# Out:
# Epoch 1/100
# 1372/1372 [==============================] - 37s 26ms/step - loss: 0.2252 - mean_absolute_error: 0.2252 - val_loss: 0.1650 - val_mean_absolute_error: 0.1650
# Epoch 2/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.1687 - mean_absolute_error: 0.1687 - val_loss: 0.1593 - val_mean_absolute_error: 0.1593
# Epoch 3/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.1479 - mean_absolute_error: 0.1479 - val_loss: 0.1540 - val_mean_absolute_error: 0.1540
# Epoch 4/100
# 1372/1372 [==============================] - 39s 29ms/step - loss: 0.1373 - mean_absolute_error: 0.1373 - val_loss: 0.1337 - val_mean_absolute_error: 0.1337
# Epoch 5/100
# 1372/1372 [==============================] - 40s 29ms/step - loss: 0.1287 - mean_absolute_error: 0.1287 - val_loss: 0.1305 - val_mean_absolute_error: 0.1305
# Epoch 6/100
# 1372/1372 [==============================] - 42s 31ms/step - loss: 0.1241 - mean_absolute_error: 0.1241 - val_loss: 0.1152 - val_mean_absolute_error: 0.1152
# Epoch 7/100
# 1372/1372 [==============================] - 38s 28ms/step - loss: 0.1186 - mean_absolute_error: 0.1186 - val_loss: 0.1282 - val_mean_absolute_error: 0.1282
# Epoch 8/100
# 1372/1372 [==============================] - 36s 26ms/step - loss: 0.1132 - mean_absolute_error: 0.1132 - val_loss: 0.1256 - val_mean_absolute_error: 0.1256
# Epoch 9/100
# 1372/1372 [==============================] - 36s 26ms/step - loss: 0.1104 - mean_absolute_error: 0.1104 - val_loss: 0.0931 - val_mean_absolute_error: 0.0931
# Epoch 10/100
# 1372/1372 [==============================] - 36s 26ms/step - loss: 0.1086 - mean_absolute_error: 0.1086 - val_loss: 0.1107 - val_mean_absolute_error: 0.1107
# Epoch 11/100
# 1372/1372 [==============================] - 36s 26ms/step - loss: 0.1070 - mean_absolute_error: 0.1070 - val_loss: 0.1018 - val_mean_absolute_error: 0.1018
# Epoch 12/100
# 1372/1372 [==============================] - 36s 26ms/step - loss: 0.1050 - mean_absolute_error: 0.1050 - val_loss: 0.0909 - val_mean_absolute_error: 0.0909
# Epoch 13/100
# 1372/1372 [==============================] - 36s 26ms/step - loss: 0.1026 - mean_absolute_error: 0.1026 - val_loss: 0.1006 - val_mean_absolute_error: 0.1006
# Epoch 14/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.1011 - mean_absolute_error: 0.1011 - val_loss: 0.1191 - val_mean_absolute_error: 0.1191
# Epoch 15/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0993 - mean_absolute_error: 0.0993 - val_loss: 0.1216 - val_mean_absolute_error: 0.1216
# Epoch 16/100
# 1372/1372 [==============================] - 36s 27ms/step - loss: 0.0999 - mean_absolute_error: 0.0999 - val_loss: 0.1152 - val_mean_absolute_error: 0.1152
# Epoch 17/100
# 1372/1372 [==============================] - 38s 28ms/step - loss: 0.0973 - mean_absolute_error: 0.0973 - val_loss: 0.0959 - val_mean_absolute_error: 0.0959
# Epoch 18/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0959 - mean_absolute_error: 0.0959 - val_loss: 0.1078 - val_mean_absolute_error: 0.1078
# Epoch 19/100
# 1372/1372 [==============================] - 38s 27ms/step - loss: 0.0939 - mean_absolute_error: 0.0939 - val_loss: 0.1008 - val_mean_absolute_error: 0.1008
# Epoch 20/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0940 - mean_absolute_error: 0.0940 - val_loss: 0.0871 - val_mean_absolute_error: 0.0871
# Epoch 21/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0924 - mean_absolute_error: 0.0924 - val_loss: 0.1043 - val_mean_absolute_error: 0.1043
# Epoch 22/100
# 1372/1372 [==============================] - 38s 27ms/step - loss: 0.0918 - mean_absolute_error: 0.0918 - val_loss: 0.0930 - val_mean_absolute_error: 0.0930
# Epoch 23/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0901 - mean_absolute_error: 0.0901 - val_loss: 0.1010 - val_mean_absolute_error: 0.1010
# Epoch 24/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0897 - mean_absolute_error: 0.0897 - val_loss: 0.0791 - val_mean_absolute_error: 0.0791
# Epoch 25/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0901 - mean_absolute_error: 0.0901 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 26/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0889 - mean_absolute_error: 0.0889 - val_loss: 0.0805 - val_mean_absolute_error: 0.0805
# Epoch 27/100
# 1372/1372 [==============================] - 38s 28ms/step - loss: 0.0882 - mean_absolute_error: 0.0882 - val_loss: 0.0922 - val_mean_absolute_error: 0.0922
# Epoch 28/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0866 - mean_absolute_error: 0.0866 - val_loss: 0.0887 - val_mean_absolute_error: 0.0887
# Epoch 29/100
# 1372/1372 [==============================] - 38s 27ms/step - loss: 0.0861 - mean_absolute_error: 0.0861 - val_loss: 0.0861 - val_mean_absolute_error: 0.0861
# Epoch 30/100
# 1372/1372 [==============================] - 39s 28ms/step - loss: 0.0855 - mean_absolute_error: 0.0855 - val_loss: 0.0812 - val_mean_absolute_error: 0.0812
# Epoch 31/100
# 1372/1372 [==============================] - 38s 28ms/step - loss: 0.0853 - mean_absolute_error: 0.0853 - val_loss: 0.0934 - val_mean_absolute_error: 0.0934
# Epoch 32/100
# 1372/1372 [==============================] - 38s 28ms/step - loss: 0.0846 - mean_absolute_error: 0.0846 - val_loss: 0.0806 - val_mean_absolute_error: 0.0806
# Epoch 33/100
# 1372/1372 [==============================] - 39s 29ms/step - loss: 0.0843 - mean_absolute_error: 0.0843 - val_loss: 0.0805 - val_mean_absolute_error: 0.0805
# Epoch 34/100
# 1372/1372 [==============================] - 39s 28ms/step - loss: 0.0831 - mean_absolute_error: 0.0831 - val_loss: 0.0903 - val_mean_absolute_error: 0.0903
# Epoch 35/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0827 - mean_absolute_error: 0.0827 - val_loss: 0.0778 - val_mean_absolute_error: 0.0778
# Epoch 36/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0824 - mean_absolute_error: 0.0824 - val_loss: 0.0919 - val_mean_absolute_error: 0.0919
# Epoch 37/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0825 - mean_absolute_error: 0.0825 - val_loss: 0.0817 - val_mean_absolute_error: 0.0817
# Epoch 38/100
# 1372/1372 [==============================] - 40s 29ms/step - loss: 0.0816 - mean_absolute_error: 0.0816 - val_loss: 0.0916 - val_mean_absolute_error: 0.0916
# Epoch 39/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0811 - mean_absolute_error: 0.0811 - val_loss: 0.1016 - val_mean_absolute_error: 0.1016
# Epoch 40/100
# 1372/1372 [==============================] - 42s 30ms/step - loss: 0.0805 - mean_absolute_error: 0.0805 - val_loss: 0.0859 - val_mean_absolute_error: 0.0859
# Epoch 41/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0806 - mean_absolute_error: 0.0806 - val_loss: 0.0705 - val_mean_absolute_error: 0.0705
# Epoch 42/100
# 1372/1372 [==============================] - 43s 32ms/step - loss: 0.0791 - mean_absolute_error: 0.0791 - val_loss: 0.0829 - val_mean_absolute_error: 0.0829
# Epoch 43/100
# 1372/1372 [==============================] - 42s 31ms/step - loss: 0.0797 - mean_absolute_error: 0.0797 - val_loss: 0.0795 - val_mean_absolute_error: 0.0795
# Epoch 44/100
# 1372/1372 [==============================] - 43s 31ms/step - loss: 0.0802 - mean_absolute_error: 0.0802 - val_loss: 0.0831 - val_mean_absolute_error: 0.0831
# Epoch 45/100
# 1372/1372 [==============================] - 42s 30ms/step - loss: 0.0798 - mean_absolute_error: 0.0798 - val_loss: 0.0839 - val_mean_absolute_error: 0.0839
# Epoch 46/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0783 - mean_absolute_error: 0.0783 - val_loss: 0.0724 - val_mean_absolute_error: 0.0724
# Epoch 47/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0795 - mean_absolute_error: 0.0795 - val_loss: 0.0734 - val_mean_absolute_error: 0.0734
# Epoch 48/100
# 1372/1372 [==============================] - 42s 30ms/step - loss: 0.0777 - mean_absolute_error: 0.0777 - val_loss: 0.0749 - val_mean_absolute_error: 0.0749
# Epoch 49/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0779 - mean_absolute_error: 0.0779 - val_loss: 0.0723 - val_mean_absolute_error: 0.0723
# Epoch 50/100
# 1372/1372 [==============================] - 42s 30ms/step - loss: 0.0779 - mean_absolute_error: 0.0779 - val_loss: 0.0783 - val_mean_absolute_error: 0.0783
# Epoch 51/100
# 1372/1372 [==============================] - 46s 34ms/step - loss: 0.0776 - mean_absolute_error: 0.0776 - val_loss: 0.0781 - val_mean_absolute_error: 0.0781
# Epoch 52/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0775 - mean_absolute_error: 0.0775 - val_loss: 0.0693 - val_mean_absolute_error: 0.0693
# Epoch 53/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0756 - mean_absolute_error: 0.0756 - val_loss: 0.0814 - val_mean_absolute_error: 0.0814
# Epoch 54/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0763 - mean_absolute_error: 0.0763 - val_loss: 0.0731 - val_mean_absolute_error: 0.0731
# Epoch 55/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0766 - mean_absolute_error: 0.0766 - val_loss: 0.0737 - val_mean_absolute_error: 0.0737
# Epoch 56/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0749 - mean_absolute_error: 0.0749 - val_loss: 0.0746 - val_mean_absolute_error: 0.0746
# Epoch 57/100
# 1372/1372 [==============================] - 44s 32ms/step - loss: 0.0748 - mean_absolute_error: 0.0748 - val_loss: 0.0971 - val_mean_absolute_error: 0.0971
# Epoch 58/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0753 - mean_absolute_error: 0.0753 - val_loss: 0.0855 - val_mean_absolute_error: 0.0855
# Epoch 59/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0752 - mean_absolute_error: 0.0752 - val_loss: 0.0856 - val_mean_absolute_error: 0.0856
# Epoch 60/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0747 - mean_absolute_error: 0.0747 - val_loss: 0.0795 - val_mean_absolute_error: 0.0795
# Epoch 61/100
# 1372/1372 [==============================] - 42s 31ms/step - loss: 0.0752 - mean_absolute_error: 0.0752 - val_loss: 0.0860 - val_mean_absolute_error: 0.0860
# Epoch 62/100
# 1372/1372 [==============================] - 43s 31ms/step - loss: 0.0743 - mean_absolute_error: 0.0743 - val_loss: 0.0685 - val_mean_absolute_error: 0.0685
# Epoch 63/100
# 1372/1372 [==============================] - 44s 32ms/step - loss: 0.0747 - mean_absolute_error: 0.0747 - val_loss: 0.0723 - val_mean_absolute_error: 0.0723
# Epoch 64/100
# 1372/1372 [==============================] - 42s 31ms/step - loss: 0.0741 - mean_absolute_error: 0.0741 - val_loss: 0.0724 - val_mean_absolute_error: 0.0724
# Epoch 65/100
# 1372/1372 [==============================] - 46s 34ms/step - loss: 0.0729 - mean_absolute_error: 0.0729 - val_loss: 0.0779 - val_mean_absolute_error: 0.0779
# Epoch 66/100
# 1372/1372 [==============================] - 44s 32ms/step - loss: 0.0733 - mean_absolute_error: 0.0733 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700
# Epoch 67/100
# 1372/1372 [==============================] - 43s 32ms/step - loss: 0.0738 - mean_absolute_error: 0.0738 - val_loss: 0.0765 - val_mean_absolute_error: 0.0765
# Epoch 68/100
# 1372/1372 [==============================] - 41s 30ms/step - loss: 0.0739 - mean_absolute_error: 0.0739 - val_loss: 0.0884 - val_mean_absolute_error: 0.0884
# Epoch 69/100
# 1372/1372 [==============================] - 40s 29ms/step - loss: 0.0738 - mean_absolute_error: 0.0738 - val_loss: 0.0705 - val_mean_absolute_error: 0.0705
# Epoch 70/100
# 1372/1372 [==============================] - 40s 29ms/step - loss: 0.0729 - mean_absolute_error: 0.0729 - val_loss: 0.0735 - val_mean_absolute_error: 0.0735
# Epoch 71/100
# 1372/1372 [==============================] - 40s 29ms/step - loss: 0.0728 - mean_absolute_error: 0.0728 - val_loss: 0.0754 - val_mean_absolute_error: 0.0754
# Epoch 72/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0711 - mean_absolute_error: 0.0711 - val_loss: 0.0711 - val_mean_absolute_error: 0.0711
# Epoch 73/100
# 1372/1372 [==============================] - 36s 26ms/step - loss: 0.0720 - mean_absolute_error: 0.0720 - val_loss: 0.0702 - val_mean_absolute_error: 0.0702
# Epoch 74/100
# 1372/1372 [==============================] - 36s 26ms/step - loss: 0.0724 - mean_absolute_error: 0.0724 - val_loss: 0.0686 - val_mean_absolute_error: 0.0686
# Epoch 75/100
# 1372/1372 [==============================] - 36s 26ms/step - loss: 0.0712 - mean_absolute_error: 0.0712 - val_loss: 0.0672 - val_mean_absolute_error: 0.0672
# Epoch 76/100
# 1372/1372 [==============================] - 36s 26ms/step - loss: 0.0716 - mean_absolute_error: 0.0716 - val_loss: 0.0697 - val_mean_absolute_error: 0.0697
# Epoch 77/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0708 - mean_absolute_error: 0.0708 - val_loss: 0.0666 - val_mean_absolute_error: 0.0666
# Epoch 78/100
# 1372/1372 [==============================] - 36s 27ms/step - loss: 0.0721 - mean_absolute_error: 0.0721 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700
# Epoch 79/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0719 - mean_absolute_error: 0.0719 - val_loss: 0.0675 - val_mean_absolute_error: 0.0675
# Epoch 80/100
# 1372/1372 [==============================] - 36s 26ms/step - loss: 0.0714 - mean_absolute_error: 0.0714 - val_loss: 0.0886 - val_mean_absolute_error: 0.0886
# Epoch 81/100
# 1372/1372 [==============================] - 36s 26ms/step - loss: 0.0719 - mean_absolute_error: 0.0719 - val_loss: 0.0726 - val_mean_absolute_error: 0.0726
# Epoch 82/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0711 - mean_absolute_error: 0.0711 - val_loss: 0.0753 - val_mean_absolute_error: 0.0753
# Epoch 83/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0703 - mean_absolute_error: 0.0703 - val_loss: 0.0746 - val_mean_absolute_error: 0.0746
# Epoch 84/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0706 - mean_absolute_error: 0.0706 - val_loss: 0.0673 - val_mean_absolute_error: 0.0673
# Epoch 85/100
# 1372/1372 [==============================] - 40s 29ms/step - loss: 0.0706 - mean_absolute_error: 0.0706 - val_loss: 0.0739 - val_mean_absolute_error: 0.0739
# Epoch 86/100
# 1372/1372 [==============================] - 39s 28ms/step - loss: 0.0706 - mean_absolute_error: 0.0706 - val_loss: 0.0650 - val_mean_absolute_error: 0.0650
# Epoch 87/100
# 1372/1372 [==============================] - 39s 28ms/step - loss: 0.0702 - mean_absolute_error: 0.0702 - val_loss: 0.0713 - val_mean_absolute_error: 0.0713
# Epoch 88/100
# 1372/1372 [==============================] - 39s 28ms/step - loss: 0.0703 - mean_absolute_error: 0.0703 - val_loss: 0.0722 - val_mean_absolute_error: 0.0722
# Epoch 89/100
# 1372/1372 [==============================] - 39s 29ms/step - loss: 0.0699 - mean_absolute_error: 0.0699 - val_loss: 0.0713 - val_mean_absolute_error: 0.0713
# Epoch 90/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0700 - mean_absolute_error: 0.0700 - val_loss: 0.0815 - val_mean_absolute_error: 0.0815
# Epoch 91/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0692 - mean_absolute_error: 0.0692 - val_loss: 0.0726 - val_mean_absolute_error: 0.0726
# Epoch 92/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0691 - mean_absolute_error: 0.0691 - val_loss: 0.0709 - val_mean_absolute_error: 0.0709
# Epoch 93/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0688 - mean_absolute_error: 0.0688 - val_loss: 0.0729 - val_mean_absolute_error: 0.0729
# Epoch 94/100
# 1372/1372 [==============================] - 38s 27ms/step - loss: 0.0694 - mean_absolute_error: 0.0694 - val_loss: 0.0811 - val_mean_absolute_error: 0.0811
# Epoch 95/100
# 1372/1372 [==============================] - 38s 27ms/step - loss: 0.0701 - mean_absolute_error: 0.0701 - val_loss: 0.0693 - val_mean_absolute_error: 0.0693
# Epoch 96/100
# 1372/1372 [==============================] - 38s 27ms/step - loss: 0.0681 - mean_absolute_error: 0.0681 - val_loss: 0.0760 - val_mean_absolute_error: 0.0760
# Epoch 97/100
# 1372/1372 [==============================] - 38s 28ms/step - loss: 0.0693 - mean_absolute_error: 0.0693 - val_loss: 0.0861 - val_mean_absolute_error: 0.0861
# Epoch 98/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0685 - mean_absolute_error: 0.0685 - val_loss: 0.0650 - val_mean_absolute_error: 0.0650
# Epoch 99/100
# 1372/1372 [==============================] - 37s 27ms/step - loss: 0.0684 - mean_absolute_error: 0.0684 - val_loss: 0.0719 - val_mean_absolute_error: 0.0719
# Epoch 100/100
# 1372/1372 [==============================] - 36s 27ms/step - loss: 0.0681 - mean_absolute_error: 0.0681 - val_loss: 0.0753 - val_mean_absolute_error: 0.0753

# %%
model = keras.models.load_model("myNN.keras")

# %%
mae = history.history['mean_absolute_error']
val_mae = history.history['val_mean_absolute_error']

plt.figure(figsize=(8, 6))
plt.plot(range(1, len(mae) + 1), mae, label='Training MAE')
plt.plot(range(1, len(val_mae) + 1), val_mae, label='Validation MAE')
plt.title('MAE vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 mae = history.history['mean_absolute_error']
#       2 val_mae = history.history['val_mean_absolute_error']
#       4 plt.figure(figsize=(8, 6))
#
# NameError: name 'history' is not defined

# %%
timestamps = [0, 0.95, 1.9, 2.95, 3.8]
timestamp_indices =[0, 244, 487, 756, 974]

plt.subplot(2,1,1)
for i in range(100):
    
    x,c =get_chaotic_x2()
    s=model.predict(x,batch_size=5000, verbose=None)
    p1,p2,p3=get_trajectories(s)
    
    plt.scatter(p2[timestamp_indices, 0], p2[timestamp_indices, 1], c='b', s=0.5)



sc = model.predict(c,batch_size=5000, verbose=None)
p1c,p2c,p3c=get_trajectories(sc)


plt.plot(p2c[:974,0],p2c[:974,1],'--', alpha=0.5, label='ANN')    
plt.scatter(p2c[974,0],p2c[974,1],c='b',marker='*',s=100)
plt.legend()
plt.subplot(2,1,2)

for i in range(100):
    
    x,c =get_chaotic_x2()
    s=pre_trained_model.predict(x,batch_size=5000, verbose=None)
    p1,p2,p3=get_trajectories(s)
    
    plt.scatter(p2[timestamp_indices, 0], p2[timestamp_indices, 1], c='b', s=0.5)



sc = pre_trained_model.predict(c,batch_size=5000, verbose=None)
p1c,p2c,p3c=get_trajectories(sc)


plt.plot(p2c[:974,0],p2c[:974,1],'--', alpha=0.5, label='Pre-Trained ANN')    
plt.scatter(p2c[974,0],p2c[974,1],c='b',marker='*', s=100)
plt.tight_layout()
plt.legend()
plt.show()

# %%
model.summary()
pre_trained_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               512
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dense_7 (Dense)             (None, 128)               16512
#
#  dense_8 (Dense)             (None, 128)               16512
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  dense_10 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 149636 (584.52 KB)
# Trainable params: 149636 (584.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3)]               0
#
#  dense (Dense)               (None, 128)               512
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dense_7 (Dense)             (None, 128)               16512
#
#  dense_8 (Dense)             (None, 128)               16512
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  dense_10 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 149636 (584.52 KB)
# Trainable params: 149636 (584.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
xt1,yt1 = get_data(train_indices[10])
xv1,yv1 = get_data(val_indices[0])

xt2,yt2 = get_data(train_indices[1])
xv2,yv2 = get_data(val_indices[1])




fig, axs = plt.subplots(2, 2, figsize=(8, 6))

yp = model.predict(xt1,batch_size=5000, verbose = None)
p1,p2,p3=get_trajectories(yp)
p1b,p2b,p3b=get_trajectories(yt1)

axs[0, 0] = plot_trajectories(p1, p2, p3, ax=axs[0, 0]) #train
axs[0,0].plot(p1b[:,0],p1b[:,1],'--', color='r')
axs[0,0].plot(p2b[:,0],p2b[:,1],'--',color='b')
axs[0,0].plot(p3b[:,0],p3b[:,1],'--',color='g')

axs[0,0].set_title('Training example 1')

yp = model.predict(xv1,batch_size=5000, verbose = None)
p1,p2,p3=get_trajectories(yp)
p1b,p2b,p3b=get_trajectories(yv1)

axs[0, 1] = plot_trajectories(p1, p2, p3, ax=axs[0, 1]) #val
axs[0,1].plot(p1b[:,0],p1b[:,1],'--', color='r')
axs[0,1].plot(p2b[:,0],p2b[:,1],'--',color='b')
axs[0,1].plot(p3b[:,0],p3b[:,1],'--',color='g')

axs[0,1].set_title('Validation example 2')

yp = model.predict(xt2,batch_size=5000, verbose = None)
p1,p2,p3=get_trajectories(yp)
p1b,p2b,p3b=get_trajectories(yt2)

axs[1, 0] = plot_trajectories(p1, p2, p3, ax=axs[1, 0]) #train
axs[1,0].plot(p1b[:,0],p1b[:,1],'--', color='r')
axs[1,0].plot(p2b[:,0],p2b[:,1],'--',color='b')
axs[1,0].plot(p3b[:,0],p3b[:,1],'--',color='g')

axs[1,0].set_title('Training example 2')

yp = model.predict(xv2,batch_size=5000, verbose = None)
p1,p2,p3=get_trajectories(yp)
p1b,p2b,p3b=get_trajectories(yv2)

axs[1, 1] = plot_trajectories(p1, p2, p3, ax=axs[1, 1]) #val
axs[1,1].plot(p1b[:,0],p1b[:,1],'--', color='r')
axs[1,1].plot(p2b[:,0],p2b[:,1],'--',color='b')
axs[1,1].plot(p3b[:,0],p3b[:,1],'--',color='g')

axs[1,1].set_title('Validation example 2')
plt.tight_layout()

plt.show()

# %%
xt1,yt1 = get_data(train_indices[10])
xv1,yv1 = get_data(val_indices[0])

xt2,yt2 = get_data(train_indices[1])
xv2,yv2 = get_data(val_indices[1])


fig, axs = plt.subplots(2, 2, figsize=(8, 6))

yp = pre_trained_model.predict(xt1,batch_size=5000, verbose = None)
p1,p2,p3=get_trajectories(yp)
p1b,p2b,p3b=get_trajectories(yt1)

axs[0,0] = plot_trajectories(p1, p2, p3, ax=axs[0, 0]) #train
axs[0,0].plot(p1b[:,0],p1b[:,1],'--', color='r')
axs[0,0].plot(p2b[:,0],p2b[:,1],'--',color='b')
axs[0,0].plot(p3b[:,0],p3b[:,1],'--',color='g')

axs[0,0].set_title('Training example 1')

yp = pre_trained_model.predict(xv1,batch_size=5000, verbose = None)
p1,p2,p3=get_trajectories(yp)
p1b,p2b,p3b=get_trajectories(yv1)

axs[0, 1] = plot_trajectories(p1, p2, p3, ax=axs[0, 1]) #val
axs[0,1].plot(p1b[:,0],p1b[:,1],'--', color='r')
axs[0,1].plot(p2b[:,0],p2b[:,1],'--',color='b')
axs[0,1].plot(p3b[:,0],p3b[:,1],'--',color='g')

axs[0,1].set_title('Validation example 2')

yp = pre_trained_model.predict(xt2,batch_size=5000, verbose = None)
p1,p2,p3=get_trajectories(yp)
p1b,p2b,p3b=get_trajectories(yt2)

axs[1, 0] = plot_trajectories(p1, p2, p3, ax=axs[1, 0]) #train
axs[1,0].plot(p1b[:,0],p1b[:,1],'--', color='r')
axs[1,0].plot(p2b[:,0],p2b[:,1],'--',color='b')
axs[1,0].plot(p3b[:,0],p3b[:,1],'--',color='g')

axs[1,0].set_title('Training example 2')

yp = pre_trained_model.predict(xv2,batch_size=5000, verbose = None)
p1,p2,p3=get_trajectories(yp)
p1b,p2b,p3b=get_trajectories(yv2)

axs[1, 1] = plot_trajectories(p1, p2, p3, ax=axs[1, 1]) #val
axs[1,1].plot(p1b[:,0],p1b[:,1],'--', color='r')
axs[1,1].plot(p2b[:,0],p2b[:,1],'--',color='b')
axs[1,1].plot(p3b[:,0],p3b[:,1],'--',color='g')
axs[1,1].set_title('Validation example 2')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Optional: Part 2 (extra task)
# * Create a helper function that extracts the velocity at each time step.
# * Compute the potential energy and the kinetic energy at each time step. The units are chosen such that the total energy is just the sum of these two.
# * Check for the conservation of energy in: (i) the data generated by `Brutus` (note that the velocities are given in the last few columns of the data file); (ii) the pre-trained model from the paper; (iii) your ANN model.
# * Create a custom loss function and re-train your model to be trained (constrained) by energy conservation. (Unfortunately, you should not expect any significant improvement in the model with the energy-conserving loss function.)
# * Reproduce Fig. 6 (with the green line being replaced by your energy-conserving ANN).

# %% [markdown]
# ### Comments and hints

# %% [markdown]
# * You should probably define helper functions that compute potential energies, velocities and kinetic energies for points along a trajectory. Note that the masses start from rest.
# * In order to construct a `tensorflow` custom loss you will need `@tf.function()` versions of the same helper functions. Within these you can only use `tensforflow` methods such as: `tf.concat()` and `tf.math.sqrt()` (i.e., `numpy` methods cannot be used for these functions).
# * See (suggested) `tensorflow` helper functions docstrings below.
# * You can define a custom loss function that assumes a batch size that is equal to the number of time steps in a trajectory. You should also make sure that the data is not shuffled so that a batch always corresponds to a trajectory. Then you can use a global time array to be used to extract velocities and therefore kinetic energies.
# * See a suggested structure of the custom loss below. You might get problems with very large kinetic and potential energies for trajectories with close encounters. A suggestion is to clip very large values of `energy_error` in the return statement of the custom energy loss by `tf.clip_by_value(energy_error, -1e6, 1e6)`.
# * The custom loss is then used in `model.compile()` via the argument `loss=custom_energy_loss`.

# %% [markdown]
# #### Helper function docstrings
# The following are just suggestions. You are allowed to construct a solution using your own helper functions.

# %%
import tensorflow as tf
from tensorflow import keras

@tf.function()
def tf_ediff1d(a):
    """
    TensorFlow equivalent of 1D difference.
    
    Args:
        a (array): A TensorFlow array of dimension (N, 1)
        
    Returns:
        diff (array): An array which gives the difference of successive elements of a.
    """
    diff = a[1:]-a[:-1]
    
    return diff

@tf.function()
def tf_compute_velocities(t, p):
    """
    Computes the velocities of the particles from the trajectories starting from rest.
    
    Args:
        t (array[float]): An array of shape (N, 1) giving time steps.
        p (array): An array of dimension (N, 2) where N is the number 
                   of time steps and the two columns give the coordinates
                   of the particle.
                             
    Returns:
        v (array): An array of dimension (N, 2) where N is the number 
                   of time steps and the two columns for each array give 
                   the x and y components for the instantaneous velocity
                   of the particle.
    """ 

    delta_px = tf_ediff1d(p[:,0])
    delta_py = tf_ediff1d(p[:,1])
    delta_t = 0.0039

    vx=delta_px/delta_t
    vy=delta_py/delta_t
    
    vx = tf.concat([tf.constant([0.0], dtype=tf.float32), vx], axis=0)
    vy = tf.concat([tf.constant([0.0], dtype=tf.float32), vy], axis=0)

    vx = tf.reshape(vx, (tf.shape(vx)[0], 1)) 
    vy = tf.reshape(vy, (tf.shape(vy)[0], 1))  
    
    v = tf.concat([vx, vy], axis=1)
                                                     
    return v

@tf.function()
def tf_compute_kinetic_energy(v):
    """
    Computes the kinetic energy for the given velocity vectors
    
    Args:
        v (array): A (N,2) array of veolcities for N time steps.
        
    Returns:
        ke (array): An array of shape (N, 1) giving the kinetic energies at each time step.
    """
    vx = v[:,0]
    vy = v[:,1]
    v_tot = vx**2+vy**2
    ke = 0.5*v_tot

    return ke

@tf.function()
def tf_compute_potential_energy(p1, p2, p3):
    """
    Computes the potential energy for the given position vectors. The value of the 
    gravitational constant is taken as 1 (G=1). The masses are the same value (m=1)
    
    Args:
        p1, p2, p3 (tuple of arrays): Three arrays of dimensions (N, 2) where N is the number 
                             of time steps and the two columns for each array give 
                             the positions of the three particles (p1, p2, p3)
                             
    Returns
        pe (array): An array of shape(N, 1) giving the potential energy at each time step
        
    """
    pe = -(1/tf.norm(p1-p2, axis = 1)+1/tf.norm(p2-p3, axis = 1)+1/tf.norm(p1-p3, axis = 1)) #minus sign? 

    return pe

# %%
# Suggested structure of the custom loss function
tlist = np.linspace(0,3.9,1000) # Which will be used in the custom loss

def custom_loss(y, y_pred):
    
    """
    A custom loss function computing error in energy conservation.
    """

    p1 = y_pred[:,:2]
    p2 = y_pred[:,2:]

    p1_x = tf.reshape(p1[:, 0], (-1, 1))
    p2_x = tf.reshape(p2[:, 0], (-1, 1))
    p1_y = tf.reshape(p1[:, 1], (-1, 1))
    p2_y = tf.reshape(p2[:, 1], (-1, 1))

    p3 = tf.concat([-(p1_x + p2_x), -(p1_y + p2_y)], axis=1)
    
    predicted_velocities_1 = tf_compute_velocities(tlist, p1) # Obtained from predicted_positions, tlist
    predicted_velocities_2 = tf_compute_velocities(tlist, p2)
    predicted_velocities_3 = tf_compute_velocities(tlist, p3)

    p1_0 = y[0,:2]
    p2_0 = y[0,2:]
   
    p1_0x = p1_0[0]
    p1_0y = p1_0[1]

    p2_0x = p2_0[0]
    p2_0y = p2_0[1]

    p3_0x = -(p1_0x + p2_0x)
    p3_0y = -(p1_0y + p2_0y)

    initial_potential_energy = -(1/tf.math.sqrt((p1_0x-p2_0x)**2+(p1_0y-p2_0y)**2)+1/tf.math.sqrt((p2_0x-p3_0x)**2+(p2_0y-p3_0y)**2)+
                                 1/tf.math.sqrt((p1_0x-p3_0x)**2+(p1_0y-p3_0y)**2))
   
    ke_predicted_trajectory_1 = tf_compute_kinetic_energy(predicted_velocities_1)
    ke_predicted_trajectory_2 = tf_compute_kinetic_energy(predicted_velocities_2)
    ke_predicted_trajectory_3 = tf_compute_kinetic_energy(predicted_velocities_3)
                                                                                        
    ke_predicted_trajectory = ke_predicted_trajectory_1 + ke_predicted_trajectory_2 + ke_predicted_trajectory_3
    pe_predicted_trajectory = tf_compute_potential_energy(p1, p2, p3)

    error = (ke_predicted_trajectory + pe_predicted_trajectory -
                 initial_potential_energy)
    
    error= tf.clip_by_value(error, -1e6, 1e6)
    energy_loss = tf.reduce_mean(tf.abs(error))
                                                    # The relative weight of the two terms in the custom loss might be tuned.
    return tf.keras.losses.MeanAbsoluteError()(y, y_pred) + 0.001*energy_loss

# %%
modelX = tf.keras.models.Sequential([
      tf.keras.layers.InputLayer(input_shape=(3)),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(4, activation='linear')
])

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))

train_dataset = train_dataset.batch(1000, drop_remainder=True)
val_dataset = val_dataset.batch(1000, drop_remainder=True)


modelX.compile(optimizer=keras.optimizers.Adam(0.001, 0.5, 0.5), loss=custom_loss, metrics=['mean_absolute_error'])

# %%
#history = modelX.fit(train_dataset, batch_size=1000, epochs=100, validation_data=val_dataset) #batchsize equals to timesteps?
#tf.keras.models.save_model(modelX, 'myNNX64.keras')

# %%
modelX = keras.models.load_model("myNNX128.keras", compile=False)

# %%
def compute_velocities(t, p):

    delta_px = np.diff(p[:,0])
    delta_py = np.diff(p[:,1])
    delta_t = 0.0039

    vx=delta_px/delta_t
    vy=delta_py/delta_t

    v = np.zeros((len(p),2))
    
    v[1:,0]=vx
    v[1:,1]=vy
    
    return v

def compute_kinetic_energy(v):

    vx = v[:,0]
    vy = v[:,1]
    v_tot = vx**2+vy**2
    ke = 0.5*v_tot

    return ke

def compute_potential_energy(p1, p2, p3):

    pe = -(1/np.linalg.norm(p1-p2, axis = 1)+1/np.linalg.norm(p2-p3, axis = 1)+1/np.linalg.norm(p1-p3, axis = 1))  

    return pe

# %%
def calculate_rel_e_error(x, y_pred):

    p1,p2,p3 = get_trajectories(y_pred)

    p1_0 = [1,0]
    p2_0 = x[0,:2]
   
    p1_0x = p1_0[0]
    p1_0y = p1_0[1]

    p2_0x = p2_0[0]
    p2_0y = p2_0[1]

    p3_0x = -(p1_0x + p2_0x)
    p3_0y = -(p1_0y + p2_0y)
    
    initial_potential_energy = -(1/np.sqrt((p1_0x-p2_0x)**2+(p1_0y-p2_0y)**2)+1/np.sqrt((p2_0x-p3_0x)**2+(p2_0y-p3_0y)**2)+
                                 1/np.sqrt((p1_0x-p3_0x)**2+(p1_0y-p3_0y)**2))




    v1 = compute_velocities(tlist, p1)
    v2 = compute_velocities(tlist, p2)
    v3 = compute_velocities(tlist, p3)
    
    ke_predicted_trajectory = compute_kinetic_energy(v1)+compute_kinetic_energy(v2)+compute_kinetic_energy(v3)
    pe_predicted_trajectory = compute_potential_energy(p1,p2,p3)
    
    error = (ke_predicted_trajectory + pe_predicted_trajectory -
                 initial_potential_energy)
    
    rel_e_error=np.abs(error/initial_potential_energy) #percentage 100?
    
    return rel_e_error

# %%
def get_brutus_v(idx):

    v1x = data[[idx], : ,5]
    v2x = data[[idx], : ,7] #conservation of momentum
    v3x = -(v1x+v2x)

    v1y = data[[idx], : ,6]
    v2y = data[[idx], : ,8]
    v3y = -(v1y+v2y)

    v1x = v1x.flatten()  
    v1y = v1y.flatten()
    v2x = v2x.flatten()
    v2y = v2y.flatten()
    v3x = v3x.flatten()
    v3y = v3y.flatten()


    
    v = np.zeros((1000, 6))

    v[:,0]=v1x
    v[:,1]=v1y
    v[:,2]=v2x
    v[:,3]=v2y
    v[:,4]=v3x
    v[:,5]=v3y
    
    return v

# %%
def calculate_brutus_error(x,y,v1,v2,v3):


    
    p1,p2,p3 = get_trajectories(y)

    
    p1_0 = [1,0]
    p2_0 = x[0,:2]
   
    p1_0x = p1_0[0]
    p1_0y = p1_0[1]

    p2_0x = p2_0[0]
    p2_0y = p2_0[1]

    p3_0x = -(p1_0x + p2_0x)
    p3_0y = -(p1_0y + p2_0y)
        
    ke_predicted_trajectory = compute_kinetic_energy(v1)+compute_kinetic_energy(v2)+compute_kinetic_energy(v3)
    
    pe_predicted_trajectory = compute_potential_energy(p1,p2,p3)
    initial_potential_energy=pe_predicted_trajectory[0]
    error = (ke_predicted_trajectory + pe_predicted_trajectory -
                 initial_potential_energy)
    
    rel_e_error=np.abs(error/initial_potential_energy) #percentage 100?

    return rel_e_error

# %%
x,y = get_data(val_indices[0])
v = get_brutus_v(val_indices[0])

brutus_error=calculate_brutus_error(x,y,v[:,:2],v[:,2:4],v[:,4:])

y_pred_modelX = modelX.predict(x,batch_size=1000)
y_pred_pre_trained_model =pre_trained_model.predict(x)

error_X = calculate_rel_e_error(x, y_pred_modelX)
error_pt = calculate_rel_e_error(x, y_pred_pre_trained_model)

plt.plot(tlist,error_X, c='b', linestyle='-',label='ANN')
plt.plot(tlist,error_pt, c='g', linestyle=':',label='Pre-Trained ANN')
plt.plot(tlist,brutus_error, c='r', linestyle='--',label='Brutus')

plt.legend()

plt.yscale('log')
plt.show()
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 32/32 [==============================] - 0s 1ms/step

# %%
xt1,yt1 = get_data(train_indices[10])
xv1,yv1 = get_data(val_indices[0])

xt2,yt2 = get_data(train_indices[1])
xv2,yv2 = get_data(val_indices[1])




fig, axs = plt.subplots(2, 2, figsize=(8, 6))

yp = modelX.predict(xt1,batch_size=5000, verbose = None)
p1,p2,p3=get_trajectories(yp)
p1b,p2b,p3b=get_trajectories(yt1)

axs[0, 0] = plot_trajectories(p1, p2, p3, ax=axs[0, 0]) #train
axs[0,0].plot(p1b[:,0],p1b[:,1],'--', color='r')
axs[0,0].plot(p2b[:,0],p2b[:,1],'--',color='b')
axs[0,0].plot(p3b[:,0],p3b[:,1],'--',color='g')

axs[0,0].set_title('Training example 1')

yp = modelX.predict(xv1,batch_size=5000, verbose = None)
p1,p2,p3=get_trajectories(yp)
p1b,p2b,p3b=get_trajectories(yv1)

axs[0, 1] = plot_trajectories(p1, p2, p3, ax=axs[0, 1]) #val
axs[0,1].plot(p1b[:,0],p1b[:,1],'--', color='r')
axs[0,1].plot(p2b[:,0],p2b[:,1],'--',color='b')
axs[0,1].plot(p3b[:,0],p3b[:,1],'--',color='g')

axs[0,1].set_title('Validation example 2')

yp = modelX.predict(xt2,batch_size=5000, verbose = None)
p1,p2,p3=get_trajectories(yp)
p1b,p2b,p3b=get_trajectories(yt2)

axs[1, 0] = plot_trajectories(p1, p2, p3, ax=axs[1, 0]) #train
axs[1,0].plot(p1b[:,0],p1b[:,1],'--', color='r')
axs[1,0].plot(p2b[:,0],p2b[:,1],'--',color='b')
axs[1,0].plot(p3b[:,0],p3b[:,1],'--',color='g')

axs[1,0].set_title('Training example 2')

yp = modelX.predict(xv2,batch_size=5000, verbose = None)
p1,p2,p3=get_trajectories(yp)
p1b,p2b,p3b=get_trajectories(yv2)

axs[1, 1] = plot_trajectories(p1, p2, p3, ax=axs[1, 1]) #val
axs[1,1].plot(p1b[:,0],p1b[:,1],'--', color='r')
axs[1,1].plot(p2b[:,0],p2b[:,1],'--',color='b')
axs[1,1].plot(p3b[:,0],p3b[:,1],'--',color='g')

axs[1,1].set_title('Validation example 2')
plt.tight_layout()

plt.show()

# %%
mae = history.history['mean_absolute_error']
val_mae = history.history['val_mean_absolute_error']

plt.figure(figsize=(8, 6))
plt.plot(range(1, len(mae) + 1), mae, label='Training MAE')
plt.plot(range(1, len(val_mae) + 1), val_mae, label='Validation MAE')
plt.title('MAE vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)
plt.show()

# %%
# %timeit modelX.predict(x,batch_size=1000, verbose=None) #for benchmarking
# Out:
# 35.9 ms ± 742 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit pre_trained_model.predict(x, verbose=None)
# Out:
# 70.4 ms ± 3.28 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit model.predict(x, verbose=None)
# Out:
# 112 ms ± 5.56 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
